# %%
x <- read.table("large.statsGit.r", sep=";")
plot((x[,3]-min(x[,3]))/3600,x[,2]/1e9,main="large instance Git")
summary(xg)
# Out:
#        V1                   V2                  V3
#  Min.   : -14833800   Min.   :0.000e+00   Min.   :1.413e+09
#  1st Qu.:     46307   1st Qu.:7.936e+09   1st Qu.:1.413e+09
#  Median :    182528   Median :1.331e+10   Median :1.413e+09
#  Mean   :   5584744   Mean   :1.280e+10   Mean   :1.413e+09
#  3rd Qu.:   1044060   3rd Qu.:1.810e+10   3rd Qu.:1.413e+09
#  Max.   :2043120000   Max.   :2.498e+10   Max.   :1.413e+09

# %%
times <- (x[,3]-min(x[,3]))/3600
sizes <- x[,2]/1e9
times[times>2.9] <- times[times>2.9]-2.9
plot(times,sizes)

# %%
x <- read.table("large.statsHg.r", sep=";")
plot((x[,3]-min(x[,3]))/3600,x[,2]/1e9,main="large instance Hg")

# %%
times <- (x[,3]-min(x[,3]))/3600
sizes <- x[,2]/1e9
times[times>15] <- times[times>15]-15
times[times>6] <- times[times>6]-6
plot(times,sizes)

# %%
x <- read.table("micro.statsHg.r", sep=";")
times <- (x[,3]-min(x[,3]))/3600
sizes <- x[,2]/1e9
times[times>10] <- times[times>10]-10

plot(times,sizes,main="micro instance Hg")

# %%
x <- read.table("micro.statsGit.r", sep=";")
times <- (x[,3]-min(x[,3]))/3600
sizes <- x[,2]/1e9
times[times>2.3] <- times[times>2.3]-2.3

plot(times,sizes,main="micro instance Hg")
